# %%
import os
os.environ['OMP_NUM_THREADS']="1"
from firedrake import *
import matplotlib.pyplot as plt
from firedrake import *
from firedrake.pyplot import triplot
import pyvista as pv
import math
import operator

# %%
nx, ny = 40, 40  # Number of cells in x and y directions.
mesh = UnitSquareMesh(nx, ny, quadrilateral=True)

# %%
dim = 2
x,y = SpatialCoordinate(mesh)

# %%
fig, axes = plt.subplots()
axes.axis('equal')
collection = triplot(mesh, axes=axes)
axes.legend()

# %%
label_top = 1
label_bottom = 2

x, y = SpatialCoordinate(mesh)
V = FunctionSpace(mesh, "DP", 0)
top_half_func = Function(V).interpolate(conditional(y > 0.5, 1., 0.))
bottom_half_func = Function(V).interpolate(conditional(y > 0.5, 0., 1.))
mesh2 = RelabeledMesh(mesh,[top_half_func,bottom_half_func],[label_top,label_bottom])

# %%
fig, axes = plt.subplots()
axes.axis('equal')
collection = triplot(mesh2, axes=axes)
axes.legend()

# %%
mesh_top = Submesh(mesh2, dim, label_top, name="mesh_v")
mesh_bottom = Submesh(mesh2, dim, label_bottom, name="mesh_c")

# %%
fig, axes = plt.subplots()
axes.axis('equal')
collection = triplot(mesh_top, axes=axes)
axes.legend()

# %%
fig, axes = plt.subplots()
axes.axis('equal')
collection = triplot(mesh_bottom, axes=axes)
axes.legend()

# %% [markdown]
# ## Base case starts here

# %%
V_top = VectorFunctionSpace(mesh_top, "CG", 2)  # Velocity function space (vector)
W_top = FunctionSpace(mesh_top, "CG", 1)  # Pressure function space (scalar)
Q_top = FunctionSpace(mesh_top, "CG", 2)  # Temperature function space (scalar)
#Z_top = MixedFunctionSpace([V_top, W_top])  # Mixed function space.
Z_top = V_top * W_top

V_bottom = VectorFunctionSpace(mesh_bottom, "CG", 2)  # Velocity function space (vector)
W_bottom = FunctionSpace(mesh_bottom, "CG", 1)  # Pressure function space (scalar)
Q_bottom = FunctionSpace(mesh_bottom, "CG", 2)  # Temperature function space (scalar)
#Z_bottom = MixedFunctionSpace([V_bottom, W_bottom])  # Mixed function space.
Z_bottom = V_bottom * W_bottom

#V = MixedFunctionSpace([V_top,V_bottom])
#W = MixedFunctionSpace([W_top,W_bottom])
#Q = MixedFunctionSpace([Q_top,Q_bottom])
#Z = MixedFunctionSpace([V_top, V_bottom, W_top, W_bottom])
V = V_top * V_bottom
W = W_top * W_bottom
Q = Q_top * Q_bottom
Z = V_top * V_bottom * W_top * W_bottom

# %%
z = Function(Z)
u_top, u_bottom, p_top, p_bottom = split(z)
for subf, name in zip(z.subfunctions, ["velocity_top", "pressure_top", "velocity_bottom", "pressure_bottom"]):
    subf.rename(name)

T = Function(Q)
T_top, T_bottom = T.subfunctions
X_top = SpatialCoordinate(mesh_top)
T_top.interpolate((1.0-X_top[1]) + (0.05*cos(pi*X_top[0])*sin(pi*X_top[1])))
X_bottom = SpatialCoordinate(mesh_bottom)
T_bottom.interpolate((1.0-X_bottom[1]) + (0.05*cos(pi*X_bottom[0])*sin(pi*X_bottom[1])))

z_test = TestFunction(Z)
u_test_top, u_test_bottom, p_test_top, p_test_bottom = split(z_test)
q_test_top, q_test_bottom = split(TestFunction(Q))

z_trial = TrialFunction(Z)
u_trial_top, u_trial_bottom, p_trial_top, p_trial_bottom = split(z_trial)
q_test_trial, q_test_trial = split(TestFunction(Q))

norm_top = FacetNormal(mesh_top)
norm_bottom = FacetNormal(mesh_bottom)

dx_top = Measure("dx", domain=mesh_top)
ds_top = Measure("ds", domain=mesh_top)
dS_top = Measure("dS", domain=mesh_top)

dx_bottom = Measure("dx", domain=mesh_bottom)
ds_bottom = Measure("ds", domain=mesh_bottom)
dS_bottom = Measure("dS", domain=mesh_bottom)

Ra = Constant(1e4)  # Rayleigh number

time = 0.0  # Initial time
delta_t = Constant(1e-3)  # Initial time-step
timesteps = 20000  # Maximum number of timesteps
steady_state_tolerance = 1e-9  # Used to determine if solution has reached a steady state.

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots()
collection = tripcolor(T_top, axes=axes, cmap='coolwarm')
fig.colorbar(collection);

# %%
fig, axes = plt.subplots()
collection = tripcolor(T_bottom, axes=axes, cmap='coolwarm')
fig.colorbar(collection);

# %%
#stokes_subspaces_top = Z_top.subspaces
#V_nullspace_top = stokes_subspaces_top[0]
#p_nullspace_top = VectorSpaceBasis(constant=True,comm=Z_top.mesh().comm)
#Z_nullspace_top = MixedVectorSpaceBasis(Z_top,[V_nullspace_top, p_nullspace_top])
#stokes_subspaces_bottom = Z_bottom.subspaces
#V_nullspace_bottom = stokes_subspaces_bottom[0]
#p_nullspace_bottom = VectorSpaceBasis(constant=True,comm=Z_bottom.mesh().comm)
#Z_nullspace_bottom = MixedVectorSpaceBasis(Z_bottom,[V_nullspace_bottom, p_nullspace_top])

stokes_subspaces = Z.subspaces
V_nullspace_top = stokes_subspaces[0]
V_nullspace_bottom = stokes_subspaces[1]
p_nullspace_top = VectorSpaceBasis(constant=True,comm=Z_top.mesh().comm)
p_nullspace_bottom = VectorSpaceBasis(constant=True,comm=Z_bottom.mesh().comm)
Z_nullspace = MixedVectorSpaceBasis(Z,[V_nullspace_top,V_nullspace_bottom,p_nullspace_top,p_nullspace_bottom])

# %% [markdown]
# ## Energy Solver

# %%
direct_energy_solver_parameters= {
    "mat_type": "aij",
    "snes_type": "ksponly",
    "ksp_type": "preonly",
    "pc_type": "lu",
    "pc_factor_mat_solver_type": "mumps",
    "snes_monitor": None,
}

# %%
def F_advection(test, trial, u, n, dx, ds):
    return trial * div(test * u) * dx - trial * dot(n,u) * test * ds
    #return 0

def F_diffusion(test, trial, dx):
    return -( inner(grad(test),grad(trial)) * dx )

def F_mass( test, trial, dx ):
    return dot(test,trial) * dx

#def F_zero( test, dx ):
#    return test * Constant(0) * dx

# %%
a = np.array([[0.5]])
b = np.array([1.0])
c = np.array([0.5])
quad_degree = 5

energy_bcs_top = [ DirichletBC(Q.sub(0),0.0,4), DirichletBC(Q.sub(0),T_top,5) ]
energy_bcs_bottom = [ DirichletBC(Q.sub(1),1.0,3), DirichletBC(Q.sub(1),T_bottom,5) ]
hom_bcs = [bci.__class__(bci.function_space(), 0, bci.sub_domain) for bci in energy_bcs_top] +[ bci.__class__(bci.function_space(), 0, bci.sub_domain) for bci in energy_bcs_bottom]

T_old = Function(Q)
T_old_top, T_old_bottom = split(T_old)

tendency = Function(Q)
tendency_top, tendency_bottom = split(tendency)

u_inner_top = T_old_top + 0.5*delta_t*tendency_top
#F_energy_top = F_mass(q_test_top,tendency_top,dx_top) - ( F_advection(q_test_top,u_inner_top,u_top,norm_top,dx_top,ds_top) + F_diffusion(q_test_top,u_inner_top,dx_top))
F_energy_top = F_mass(q_test_top,tendency_top,dx_top)

u_inner_bottom = T_old_bottom + 0.5*delta_t*tendency_bottom
F_energy_bottom = F_mass(q_test_bottom,tendency_bottom,dx_bottom) - ( F_advection(q_test_bottom,u_inner_bottom,u_bottom,norm_bottom,dx_bottom,ds_bottom) + F_diffusion(q_test_bottom,u_inner_bottom,dx_bottom))


energy_problem = NonlinearVariationalProblem(F_energy_top + F_energy_bottom,tendency,bcs=hom_bcs)
energy_solver = NonlinearVariationalSolver(energy_problem, solver_parameters=direct_energy_solver_parameters)
sol_expr_top = tendency.sub(0) * 0.5*delta_t
sol_expr_bottom = tendency.sub(1) * 0.5 * delta_t
final_sol_expr_top = T_old.sub(0) + tendency.sub(0) * delta_t
final_sol_expr_bottom = T_old.sub(1) + tendency.sub(1) * delta_t

# %%
tendency.subfunctions
# Out:
# (Coefficient(WithGeometry(IndexedProxyFunctionSpace(<firedrake.mesh.MeshTopology object at 0x7f17acc1e870>, FiniteElement('Q', quadrilateral, 2), name=None, index=0, component=None), Mesh(VectorElement(FiniteElement('Q', quadrilateral, 1), dim=2), 8)), 42),
#  Coefficient(WithGeometry(IndexedProxyFunctionSpace(<firedrake.mesh.MeshTopology object at 0x7f17acc1fc80>, FiniteElement('Q', quadrilateral, 2), name=None, index=1, component=None), Mesh(VectorElement(FiniteElement('Q', quadrilateral, 1), dim=2), 10)), 43))

# %% [markdown]
# ## Stokes solver

# %%
stokes_solver_parameters = {"snes_type": "ksponly",
    "mat_type": "aij",
    "ksp_type": "preonly",
    "pc_type": "lu",
    "pc_factor_mat_solver_type": "mumps",
#    "snes_monitor": None,
}

# %%
### Stokes Solver
stokes_bcs = [ 
    DirichletBC(Z.sub(0).sub(0), 0.0, 1), 
    DirichletBC(Z.sub(0).sub(0), 0.0, 2), 
    DirichletBC(Z.sub(0).sub(1), 0.0, 4),
    DirichletBC(Z.sub(0).sub(1), 0.0, 5),
    DirichletBC(Z.sub(1).sub(0), 0.0, 1), 
    DirichletBC(Z.sub(1).sub(0), 0.0, 2), 
    DirichletBC(Z.sub(1).sub(1), 0.0, 3),
    DirichletBC(Z.sub(1).sub(1), 0.0, 5),
]

stress_top = 2 * sym(grad(u_top))
stress_bottom = 2 * sym(grad(u_bottom))
source_top = ( Ra * T_top ) * as_vector([0,1])
source_bottom = ( Ra * T_bottom ) * as_vector([0,1])

def F_viscosity(test,stress,dx):
    return -( inner(nabla_grad(test),stress ) * dx )

def F_pressure_gradient(test, p, dx):
    return dot(div(test),p) * dx

def F_divergence(test, u, dx):
    return dot(test, div(u)) * dx

def F_momentum_source(test,source,dx):
    return dot(test,source) * dx

F_stokes_top = -F_momentum_source(u_test_top,source_top,dx_top) - F_pressure_gradient(u_test_top,p_top,dx_top) - F_viscosity(u_test_top,stress_top,dx_top) - F_divergence(p_test_top,u_top,dx_top)
F_stokes_bottom = -F_momentum_source(u_test_bottom,source_bottom,dx_bottom) - F_pressure_gradient(u_test_bottom,p_bottom,dx_bottom) - F_viscosity(u_test_bottom,stress_bottom,dx_bottom) - F_divergence(p_test_bottom,u_bottom,dx_bottom)

stokes_problem = NonlinearVariationalProblem(F_stokes_top + F_stokes_bottom,z,bcs=stokes_bcs)
stokes_solver = NonlinearVariationalSolver(stokes_problem,solver_parameters=stokes_solver_parameters,nullspace=Z_nullspace,transpose_nullspace=Z_nullspace)

# %%
for timestep in range(0,timesteps):

    stokes_solver.solve()

    for bci in energy_bcs_top:
        bci.apply(T)
    for bci in energy_bcs_bottom:
        bci.apply(T)
    for subfunction, subfunction_0 in zip(T.subfunctions, T_old.subfunctions):
        subfunction_0.assign(subfunction)

    energy_solver.solve()

    T.sub(0).assign(T_old.sub(0) + sol_expr_top)
    T.sub(1).assign(T_old.sub(1) + sol_expr_bottom)
    T.sub(0).assign(final_sol_expr_top)
    T.sub(1).assign(final_sol_expr_bottom)

    maxchange = sqrt(assemble((T.sub(0) - T_old.sub(0))**2 * dx_top) + assemble((T.sub(1) - T_old.sub(1))**2 * dx_bottom))
    if maxchange < steady_state_tolerance:
        print("Done?")
        break
    #if timestep == 10:
    #    break
# Out:
#   0 SNES Function norm 5.232611331366e-03
#   1 SNES Function norm 2.108872181750e-16
#   0 SNES Function norm 1.995959885502e-03
#   1 SNES Function norm 2.110340528751e-16
#   0 SNES Function norm 1.096243994811e-03
#   1 SNES Function norm 2.098947504837e-16
#   0 SNES Function norm 8.019968660925e-04
#   1 SNES Function norm 2.156785787180e-16
#   0 SNES Function norm 6.088274229927e-04
#   1 SNES Function norm 2.269997652551e-16
#   0 SNES Function norm 5.015363677700e-04
#   1 SNES Function norm 2.212822982530e-16
#   0 SNES Function norm 4.109333518472e-04
#   1 SNES Function norm 2.285524860256e-16
#   0 SNES Function norm 3.562310760779e-04
#   1 SNES Function norm 2.364748751566e-16
#   0 SNES Function norm 3.046743611020e-04
#   1 SNES Function norm 2.358552976929e-16
#   0 SNES Function norm 2.719400390196e-04
#   1 SNES Function norm 2.303521214912e-16
#   0 SNES Function norm 2.391765971771e-04
#   1 SNES Function norm 2.361212899859e-16
#   0 SNES Function norm 2.171714739030e-04
#   1 SNES Function norm 2.350020291251e-16
#   0 SNES Function norm 1.947466125597e-04
#   1 SNES Function norm 2.457075039003e-16
#   0 SNES Function norm 1.786265741746e-04
#   1 SNES Function norm 2.479492361139e-16
#   0 SNES Function norm 1.625108681033e-04
#   1 SNES Function norm 2.496863687200e-16
#   0 SNES Function norm 1.499671391468e-04
#   1 SNES Function norm 2.549316619492e-16
#   0 SNES Function norm 1.380300413065e-04
#   1 SNES Function norm 2.593892145511e-16
#   0 SNES Function norm 1.278554844413e-04
#   1 SNES Function norm 2.638620988106e-16
#   0 SNES Function norm 1.188593159648e-04
#   1 SNES Function norm 2.632282837497e-16
#   0 SNES Function norm 1.103647037447e-04
#   1 SNES Function norm 2.700543198515e-16
#   0 SNES Function norm 1.035292231381e-04
#   1 SNES Function norm 2.645556367510e-16
#   0 SNES Function norm 9.628954107357e-05
#   1 SNES Function norm 2.759302030220e-16
#   0 SNES Function norm 9.108917153447e-05
#   1 SNES Function norm 2.739711413857e-16
#   0 SNES Function norm 8.482543865651e-05
#   1 SNES Function norm 2.842852772423e-16
#   0 SNES Function norm 8.088743460431e-05
#   1 SNES Function norm 2.740068128353e-16
#   0 SNES Function norm 7.540729270950e-05
#   1 SNES Function norm 2.789336360358e-16
#   0 SNES Function norm 7.245660013811e-05
#   1 SNES Function norm 2.845972405185e-16
#   0 SNES Function norm 6.762206682957e-05
#   1 SNES Function norm 2.845659821098e-16
#   0 SNES Function norm 6.544934537162e-05
#   1 SNES Function norm 2.852061162027e-16
#   0 SNES Function norm 6.115805296564e-05
#   1 SNES Function norm 2.943727369593e-16
#   0 SNES Function norm 5.960004703388e-05
#   1 SNES Function norm 2.899408037864e-16
#   0 SNES Function norm 5.577368672849e-05
#   1 SNES Function norm 2.988166219101e-16
#   0 SNES Function norm 5.470064548750e-05
#   1 SNES Function norm 2.924815914582e-16
#   0 SNES Function norm 5.127753786400e-05
#   1 SNES Function norm 2.870513000333e-16
#   0 SNES Function norm 5.058489367592e-05
#   1 SNES Function norm 2.907226441302e-16
#   0 SNES Function norm 4.751507241479e-05
#   1 SNES Function norm 3.029322598504e-16
#   0 SNES Function norm 4.711779492908e-05
#   1 SNES Function norm 3.022787405733e-16
#   0 SNES Function norm 4.435970207806e-05
#   1 SNES Function norm 3.073578569723e-16
#   0 SNES Function norm 4.418836602216e-05
#   1 SNES Function norm 3.031706307298e-16
#   0 SNES Function norm 4.170662121438e-05
#   1 SNES Function norm 3.157530825423e-16
#   0 SNES Function norm 4.170457321618e-05
#   1 SNES Function norm 3.181966868810e-16
#   0 SNES Function norm 3.946847447841e-05
#   1 SNES Function norm 3.236858592411e-16
#   0 SNES Function norm 3.958969839831e-05
#   1 SNES Function norm 3.141757019724e-16
#   0 SNES Function norm 3.757222270697e-05
#   1 SNES Function norm 3.201397894092e-16
#   0 SNES Function norm 3.777964654792e-05
#   1 SNES Function norm 3.152867606737e-16
#   0 SNES Function norm 3.595678614936e-05
#   1 SNES Function norm 3.275379687163e-16
#   0 SNES Function norm 3.622087360198e-05
#   1 SNES Function norm 3.245137881264e-16
#   0 SNES Function norm 3.457119040087e-05
#   1 SNES Function norm 3.355203631955e-16
#   0 SNES Function norm 3.486872845145e-05
#   1 SNES Function norm 3.258260295004e-16
#   0 SNES Function norm 3.337304341344e-05
#   1 SNES Function norm 3.384781712634e-16
#   0 SNES Function norm 3.368608088982e-05
#   1 SNES Function norm 3.204440253172e-16
#   0 SNES Function norm 3.232724234175e-05
#   1 SNES Function norm 3.373203622347e-16
#   0 SNES Function norm 3.264215874709e-05
#   1 SNES Function norm 3.378592053574e-16
#   0 SNES Function norm 3.140485407172e-05
#   1 SNES Function norm 3.505803548440e-16
#   0 SNES Function norm 3.171154925594e-05
#   1 SNES Function norm 3.450244448053e-16
#   0 SNES Function norm 3.058213948378e-05
#   1 SNES Function norm 3.274656028114e-16
#   0 SNES Function norm 3.087333793830e-05
#   1 SNES Function norm 3.417707933855e-16
#   0 SNES Function norm 2.983970480188e-05
#   1 SNES Function norm 3.414475131801e-16
#   0 SNES Function norm 3.011036765188e-05
#   1 SNES Function norm 3.458379097853e-16
#   0 SNES Function norm 2.916176884559e-05
#   1 SNES Function norm 3.452522801407e-16
#   0 SNES Function norm 2.940860469352e-05
#   1 SNES Function norm 3.524130453043e-16
#   0 SNES Function norm 2.853553641832e-05
#   1 SNES Function norm 3.513589288976e-16
#   0 SNES Function norm 2.875660047313e-05
#   1 SNES Function norm 3.588990977845e-16
#   0 SNES Function norm 2.795066782308e-05
#   1 SNES Function norm 3.454882154172e-16
#   0 SNES Function norm 2.814503786174e-05
#   1 SNES Function norm 3.708856589169e-16
#   0 SNES Function norm 2.739883400011e-05
#   1 SNES Function norm 3.559280784333e-16
#   0 SNES Function norm 2.756635166096e-05
#   1 SNES Function norm 3.564299218278e-16
#   0 SNES Function norm 2.687334655994e-05
#   1 SNES Function norm 3.505767818681e-16
#   0 SNES Function norm 2.701441310264e-05
#   1 SNES Function norm 3.695985085452e-16
#   0 SNES Function norm 2.636885226297e-05
#   1 SNES Function norm 3.593827637874e-16
#   0 SNES Function norm 2.648426898892e-05
#   1 SNES Function norm 3.693542080104e-16
#   0 SNES Function norm 2.588108215088e-05
#   1 SNES Function norm 3.737007143408e-16
#   0 SNES Function norm 2.597192692702e-05
#   1 SNES Function norm 3.711311400597e-16
#   0 SNES Function norm 2.540664646215e-05
#   1 SNES Function norm 3.735401538159e-16
#   0 SNES Function norm 2.547417911474e-05
#   1 SNES Function norm 3.767361848560e-16
#   0 SNES Function norm 2.494286753275e-05
#   1 SNES Function norm 3.699025283121e-16
#   0 SNES Function norm 2.498845808756e-05
#   1 SNES Function norm 3.740598801342e-16
#   0 SNES Function norm 2.448764395927e-05
#   1 SNES Function norm 3.674353096355e-16
#   0 SNES Function norm 2.451271881661e-05
#   1 SNES Function norm 3.750744039789e-16
#   0 SNES Function norm 2.403934035251e-05
#   1 SNES Function norm 3.814358749206e-16
#   0 SNES Function norm 2.404534242871e-05
#   1 SNES Function norm 3.803249454882e-16
#   0 SNES Function norm 2.359669791096e-05
#   1 SNES Function norm 3.801781753057e-16
#   0 SNES Function norm 2.358505760072e-05
#   1 SNES Function norm 3.787962907158e-16
#   0 SNES Function norm 2.315876190382e-05
#   1 SNES Function norm 3.896663287106e-16
#   0 SNES Function norm 2.313087635958e-05
#   1 SNES Function norm 3.883881210024e-16
#   0 SNES Function norm 2.272482284958e-05
#   1 SNES Function norm 3.889203890464e-16
#   0 SNES Function norm 2.268204161128e-05
#   1 SNES Function norm 4.075210425033e-16
#   0 SNES Function norm 2.229436876340e-05
#   1 SNES Function norm 4.099581303402e-16
#   0 SNES Function norm 2.223798421004e-05
#   1 SNES Function norm 3.850197794371e-16
#   0 SNES Function norm 2.186704635052e-05
#   1 SNES Function norm 3.948970481376e-16
#   0 SNES Function norm 2.179828778205e-05
#   1 SNES Function norm 3.995000110366e-16
#   0 SNES Function norm 2.144262943589e-05
#   1 SNES Function norm 3.995020507710e-16
#   0 SNES Function norm 2.136265985776e-05
#   1 SNES Function norm 3.938646112946e-16
#   0 SNES Function norm 2.102099323187e-05
#   1 SNES Function norm 4.073337700070e-16
#   0 SNES Function norm 2.093090814498e-05
#   1 SNES Function norm 3.936508023346e-16
#   0 SNES Function norm 2.060209334892e-05
#   1 SNES Function norm 3.967026065827e-16
#   0 SNES Function norm 2.050292098152e-05
#   1 SNES Function norm 4.028016886122e-16
#   0 SNES Function norm 2.018594863250e-05
#   1 SNES Function norm 4.124078642501e-16
#   0 SNES Function norm 2.007865121579e-05
#   1 SNES Function norm 3.938311100220e-16
#   0 SNES Function norm 1.977262712315e-05
#   1 SNES Function norm 3.914049523902e-16
#   0 SNES Function norm 1.965810288130e-05
#   1 SNES Function norm 4.118118132180e-16
#   0 SNES Function norm 1.936223454692e-05
#   1 SNES Function norm 3.987139498944e-16
#   0 SNES Function norm 1.924132016999e-05
#   1 SNES Function norm 4.160399272116e-16
#   0 SNES Function norm 1.895490487743e-05
#   1 SNES Function norm 4.193642602482e-16
#   0 SNES Function norm 1.882837829234e-05
#   1 SNES Function norm 3.919827599224e-16
#   0 SNES Function norm 1.855079258632e-05
#   1 SNES Function norm 4.271132661287e-16
#   0 SNES Function norm 1.841937590038e-05
#   1 SNES Function norm 4.180259588809e-16
#   0 SNES Function norm 1.815006628463e-05
#   1 SNES Function norm 4.260403828777e-16
#   0 SNES Function norm 1.801442879387e-05
#   1 SNES Function norm 3.935748958998e-16
#   0 SNES Function norm 1.775290350505e-05
#   1 SNES Function norm 4.341049061974e-16
#   0 SNES Function norm 1.761366470489e-05
#   1 SNES Function norm 4.205808376040e-16
#   0 SNES Function norm 1.735948642441e-05
#   1 SNES Function norm 4.098121941533e-16
#   0 SNES Function norm 1.721721896938e-05
#   1 SNES Function norm 4.196140633507e-16
#   0 SNES Function norm 1.696999837094e-05
#   1 SNES Function norm 4.181531696999e-16
#   0 SNES Function norm 1.682523094727e-05
#   1 SNES Function norm 4.042689771414e-16
#   0 SNES Function norm 1.658462097649e-05
#   1 SNES Function norm 4.164958622957e-16
#   0 SNES Function norm 1.643784106427e-05
#   1 SNES Function norm 4.189367892688e-16
#   0 SNES Function norm 1.620353187331e-05
#   1 SNES Function norm 4.272981725791e-16
#   0 SNES Function norm 1.605518838414e-05
#   1 SNES Function norm 4.282210027913e-16
#   0 SNES Function norm 1.582690283844e-05
#   1 SNES Function norm 4.297149150960e-16
#   0 SNES Function norm 1.567740862211e-05
#   1 SNES Function norm 4.218093348579e-16
#   0 SNES Function norm 1.545489831897e-05
#   1 SNES Function norm 4.355296226524e-16
#   0 SNES Function norm 1.530463253646e-05
#   1 SNES Function norm 4.389348727174e-16
#   0 SNES Function norm 1.508767427578e-05
#   1 SNES Function norm 4.286397551243e-16
#   0 SNES Function norm 1.493698463443e-05
#   1 SNES Function norm 4.428606983976e-16
#   0 SNES Function norm 1.472537729803e-05
#   1 SNES Function norm 4.356226542044e-16
#   0 SNES Function norm 1.457458215293e-05
#   1 SNES Function norm 4.412273518694e-16
#   0 SNES Function norm 1.436814393800e-05
#   1 SNES Function norm 4.325576822905e-16
#   0 SNES Function norm 1.421753426998e-05
#   1 SNES Function norm 4.327483627527e-16
#   0 SNES Function norm 1.401610024334e-05
#   1 SNES Function norm 4.367890101828e-16
#   0 SNES Function norm 1.386594151079e-05
#   1 SNES Function norm 4.245451594653e-16
#   0 SNES Function norm 1.366936144688e-05
#   1 SNES Function norm 4.217236021743e-16
#   0 SNES Function norm 1.351989532415e-05
#   1 SNES Function norm 4.364239577977e-16
#   0 SNES Function norm 1.332803179445e-05
#   1 SNES Function norm 4.337212137342e-16
#   0 SNES Function norm 1.317947779796e-05
#   1 SNES Function norm 4.407425545351e-16
#   0 SNES Function norm 1.299220449356e-05
#   1 SNES Function norm 4.317144574512e-16
#   0 SNES Function norm 1.284476149766e-05
#   1 SNES Function norm 4.295219883956e-16
#   0 SNES Function norm 1.266196174863e-05
#   1 SNES Function norm 4.431574137529e-16
#   0 SNES Function norm 1.251580941367e-05
#   1 SNES Function norm 4.467939951947e-16
#   0 SNES Function norm 1.233737488614e-05
#   1 SNES Function norm 4.366484668150e-16
#   0 SNES Function norm 1.219267499059e-05
#   1 SNES Function norm 4.283813558128e-16
#   0 SNES Function norm 1.201850454495e-05
#   1 SNES Function norm 4.432303704193e-16
#   0 SNES Function norm 1.187540223169e-05
#   1 SNES Function norm 4.416534947221e-16
#   0 SNES Function norm 1.170540092429e-05
#   1 SNES Function norm 4.389846862728e-16
#   0 SNES Function norm 1.156402586753e-05
#   1 SNES Function norm 4.404523262115e-16
#   0 SNES Function norm 1.139810407789e-05
#   1 SNES Function norm 4.406017434042e-16
#   0 SNES Function norm 1.125857157533e-05
#   1 SNES Function norm 4.425431524303e-16
#   0 SNES Function norm 1.109664424559e-05
#   1 SNES Function norm 4.433750898584e-16
#   0 SNES Function norm 1.095905623982e-05
#   1 SNES Function norm 4.454307785053e-16
#   0 SNES Function norm 1.080104221750e-05
#   1 SNES Function norm 4.426001627912e-16
#   0 SNES Function norm 1.066548825073e-05
#   1 SNES Function norm 4.674562810532e-16
#   0 SNES Function norm 1.051130971839e-05
#   1 SNES Function norm 4.435364024115e-16
#   0 SNES Function norm 1.037786782932e-05
#   1 SNES Function norm 4.466191800256e-16
#   0 SNES Function norm 1.022744981012e-05
#   1 SNES Function norm 4.509172360926e-16
#   0 SNES Function norm 1.009618737531e-05
#   1 SNES Function norm 4.602128766124e-16
#   0 SNES Function norm 9.949457309620e-06
#   1 SNES Function norm 4.471133790627e-16
#   0 SNES Function norm 9.820431828571e-06
#   1 SNES Function norm 4.546083109492e-16
#   0 SNES Function norm 9.677319214333e-06
#   1 SNES Function norm 4.590639681505e-16
#   0 SNES Function norm 9.550579044668e-06
#   1 SNES Function norm 4.395570291943e-16
#   0 SNES Function norm 9.411015130192e-06
#   1 SNES Function norm 4.574205323892e-16
#   0 SNES Function norm 9.286600178879e-06
#   1 SNES Function norm 4.696570774704e-16
#   0 SNES Function norm 9.150517703916e-06
#   1 SNES Function norm 4.218954519108e-16
#   0 SNES Function norm 9.028460072050e-06
#   1 SNES Function norm 4.569380702117e-16
#   0 SNES Function norm 8.895793049497e-06
#   1 SNES Function norm 4.660599400098e-16
#   0 SNES Function norm 8.776117639595e-06
#   1 SNES Function norm 4.559658115977e-16
#   0 SNES Function norm 8.646801175556e-06
#   1 SNES Function norm 4.556509661037e-16
#   0 SNES Function norm 8.529526257999e-06
#   1 SNES Function norm 4.499325404296e-16
#   0 SNES Function norm 8.403496402055e-06
#   1 SNES Function norm 4.518859062014e-16
#   0 SNES Function norm 8.288634146956e-06
#   1 SNES Function norm 4.738118445283e-16
#   0 SNES Function norm 8.165827770965e-06
#   1 SNES Function norm 4.520826900142e-16
#   0 SNES Function norm 8.053384746277e-06
#   1 SNES Function norm 4.614721107671e-16
#   0 SNES Function norm 7.933739449950e-06
#   1 SNES Function norm 4.546477756876e-16
#   0 SNES Function norm 7.823717083748e-06
#   1 SNES Function norm 4.598978701487e-16
#   0 SNES Function norm 7.707171119721e-06
#   1 SNES Function norm 4.603140783910e-16
#   0 SNES Function norm 7.599566137839e-06
#   1 SNES Function norm 4.617444236192e-16
#   0 SNES Function norm 7.486058351217e-06
#   1 SNES Function norm 4.621060080886e-16
#   0 SNES Function norm 7.380863187173e-06
#   1 SNES Function norm 4.616406933786e-16
#   0 SNES Function norm 7.270332972999e-06
#   1 SNES Function norm 4.899999982993e-16
#   0 SNES Function norm 7.167536149282e-06
#   1 SNES Function norm 4.727336824872e-16
#   0 SNES Function norm 7.059923423893e-06
#   1 SNES Function norm 4.781411630594e-16
#   0 SNES Function norm 6.959509905051e-06
#   1 SNES Function norm 4.619234613488e-16
#   0 SNES Function norm 6.854755090205e-06
#   1 SNES Function norm 4.512330602785e-16
#   0 SNES Function norm 6.756706618698e-06
#   1 SNES Function norm 4.864489734488e-16
#   0 SNES Function norm 6.654750628432e-06
#   1 SNES Function norm 4.704035181151e-16
#   0 SNES Function norm 6.559046036608e-06
#   1 SNES Function norm 4.822283843122e-16
#   0 SNES Function norm 6.459830277013e-06
#   1 SNES Function norm 4.822133231836e-16
#   0 SNES Function norm 6.366445775418e-06
#   1 SNES Function norm 4.692351931688e-16
#   0 SNES Function norm 6.269912150089e-06
#   1 SNES Function norm 4.507049102101e-16
#   0 SNES Function norm 6.178821599739e-06
#   1 SNES Function norm 4.551005654077e-16
#   0 SNES Function norm 6.084912518596e-06
#   1 SNES Function norm 4.521365542708e-16
#   0 SNES Function norm 5.996087681437e-06
#   1 SNES Function norm 4.771911851652e-16
#   0 SNES Function norm 5.904746076018e-06
#   1 SNES Function norm 4.882027602752e-16
#   0 SNES Function norm 5.818156850616e-06
#   1 SNES Function norm 4.589131018766e-16
#   0 SNES Function norm 5.729326188016e-06
#   1 SNES Function norm 4.641468547024e-16
#   0 SNES Function norm 5.644940830667e-06
#   1 SNES Function norm 4.659642454194e-16
#   0 SNES Function norm 5.558565133007e-06
#   1 SNES Function norm 4.646443721666e-16
#   0 SNES Function norm 5.476350457804e-06
#   1 SNES Function norm 4.665820679766e-16
#   0 SNES Function norm 5.392374323451e-06
#   1 SNES Function norm 4.722039187111e-16
#   0 SNES Function norm 5.312295892907e-06
#   1 SNES Function norm 4.589907997985e-16
#   0 SNES Function norm 5.230664517632e-06
#   1 SNES Function norm 4.573670788450e-16
#   0 SNES Function norm 5.152686814741e-06
#   1 SNES Function norm 4.612660570628e-16
#   0 SNES Function norm 5.073346016238e-06
#   1 SNES Function norm 4.874973590896e-16
#   0 SNES Function norm 4.997432606845e-06
#   1 SNES Function norm 4.622984347902e-16
#   0 SNES Function norm 4.920328842920e-06
#   1 SNES Function norm 4.643832078443e-16
#   0 SNES Function norm 4.846442529204e-06
#   1 SNES Function norm 4.819244526793e-16
#   0 SNES Function norm 4.771522920241e-06
#   1 SNES Function norm 4.689254543180e-16
#   0 SNES Function norm 4.699625876536e-06
#   1 SNES Function norm 4.586311379010e-16
#   0 SNES Function norm 4.626838227216e-06
#   1 SNES Function norm 4.703675841771e-16
#   0 SNES Function norm 4.556892127947e-06
#   1 SNES Function norm 4.686427229782e-16
#   0 SNES Function norm 4.486184947258e-06
#   1 SNES Function norm 4.728701078028e-16
#   0 SNES Function norm 4.418151086353e-06
#   1 SNES Function norm 4.629069074242e-16
#   0 SNES Function norm 4.349473605458e-06
#   1 SNES Function norm 4.808003809101e-16
#   0 SNES Function norm 4.283313003628e-06
#   1 SNES Function norm 4.647648910782e-16
#   0 SNES Function norm 4.216615195190e-06
#   1 SNES Function norm 4.728188262537e-16
#   0 SNES Function norm 4.152288699620e-06
#   1 SNES Function norm 4.583406813724e-16
#   0 SNES Function norm 4.087521293423e-06
#   1 SNES Function norm 4.629692535323e-16
#   0 SNES Function norm 4.024989670052e-06
#   1 SNES Function norm 4.738870507966e-16
#   0 SNES Function norm 3.962104167581e-06
#   1 SNES Function norm 4.837830859793e-16
#   0 SNES Function norm 3.901328184995e-06
#   1 SNES Function norm 4.739234229561e-16
#   0 SNES Function norm 3.840276873313e-06
#   1 SNES Function norm 4.691464698657e-16
#   0 SNES Function norm 3.781217377270e-06
#   1 SNES Function norm 4.543661949701e-16
#   0 SNES Function norm 3.721953343105e-06
#   1 SNES Function norm 4.604127164798e-16
#   0 SNES Function norm 3.664571326859e-06
#   1 SNES Function norm 4.632987155252e-16
#   0 SNES Function norm 3.607048465072e-06
#   1 SNES Function norm 4.708156143518e-16
#   0 SNES Function norm 3.551305131761e-06
#   1 SNES Function norm 4.763736189603e-16
#   0 SNES Function norm 3.495478156360e-06
#   1 SNES Function norm 4.882218511371e-16
#   0 SNES Function norm 3.441334978797e-06
#   1 SNES Function norm 4.581756704458e-16
#   0 SNES Function norm 3.387159425684e-06
#   1 SNES Function norm 4.770390157387e-16
#   0 SNES Function norm 3.334578198143e-06
#   1 SNES Function norm 4.699014655810e-16
#   0 SNES Function norm 3.282010436340e-06
#   1 SNES Function norm 4.893245267076e-16
#   0 SNES Function norm 3.230953316670e-06
#   1 SNES Function norm 4.817980587617e-16
#   0 SNES Function norm 3.179950552130e-06
#   1 SNES Function norm 4.763564161226e-16
#   0 SNES Function norm 3.130380107550e-06
#   1 SNES Function norm 4.600758954157e-16
#   0 SNES Function norm 3.080900385031e-06
#   1 SNES Function norm 4.753231138907e-16
#   0 SNES Function norm 3.032779626998e-06
#   1 SNES Function norm 4.876401641599e-16
#   0 SNES Function norm 2.984781832867e-06
#   1 SNES Function norm 5.028756252648e-16
#   0 SNES Function norm 2.938074252685e-06
#   1 SNES Function norm 4.647653370448e-16
#   0 SNES Function norm 2.891518114260e-06
#   1 SNES Function norm 4.594737156763e-16
#   0 SNES Function norm 2.846187709821e-06
#   1 SNES Function norm 4.574975504569e-16
#   0 SNES Function norm 2.801033796574e-06
#   1 SNES Function norm 4.748429992964e-16
#   0 SNES Function norm 2.757045099974e-06
#   1 SNES Function norm 4.830100395636e-16
#   0 SNES Function norm 2.713254819452e-06
#   1 SNES Function norm 4.767063461781e-16
#   0 SNES Function norm 2.670572918152e-06
#   1 SNES Function norm 4.759674264325e-16
#   0 SNES Function norm 2.628108514729e-06
#   1 SNES Function norm 4.768637737423e-16
#   0 SNES Function norm 2.586699071164e-06
#   1 SNES Function norm 4.630205079200e-16
#   0 SNES Function norm 2.545523622051e-06
#   1 SNES Function norm 4.664373273162e-16
#   0 SNES Function norm 2.505352888546e-06
#   1 SNES Function norm 4.731379542444e-16
#   0 SNES Function norm 2.465430298697e-06
#   1 SNES Function norm 4.867437498781e-16
#   0 SNES Function norm 2.426465134211e-06
#   1 SNES Function norm 4.863806155203e-16
#   0 SNES Function norm 2.387760128159e-06
#   1 SNES Function norm 4.812490385594e-16
#   0 SNES Function norm 2.349968007267e-06
#   1 SNES Function norm 4.822771622191e-16
#   0 SNES Function norm 2.312446125993e-06
#   1 SNES Function norm 4.689919948678e-16
#   0 SNES Function norm 2.275795148863e-06
#   1 SNES Function norm 4.878874576936e-16
#   0 SNES Function norm 2.239422739103e-06
#   1 SNES Function norm 4.882475647595e-16
#   0 SNES Function norm 2.203881638539e-06
#   1 SNES Function norm 4.789424568775e-16
#   0 SNES Function norm 2.168625846772e-06
#   1 SNES Function norm 4.921460114280e-16
#   0 SNES Function norm 2.134163991293e-06
#   1 SNES Function norm 4.806065162156e-16
#   0 SNES Function norm 2.099992755879e-06
#   1 SNES Function norm 4.930708227313e-16
#   0 SNES Function norm 2.066580154529e-06
#   1 SNES Function norm 4.806336626674e-16
#   0 SNES Function norm 2.033462193317e-06
#   1 SNES Function norm 4.955580111796e-16
#   0 SNES Function norm 2.001069496973e-06
#   1 SNES Function norm 4.513040692098e-16
#   0 SNES Function norm 1.968974300001e-06
#   1 SNES Function norm 4.924957698500e-16
#   0 SNES Function norm 1.937572804053e-06
#   1 SNES Function norm 4.828678630709e-16
#   0 SNES Function norm 1.906470618025e-06
#   1 SNES Function norm 5.095604301603e-16
#   0 SNES Function norm 1.876032259104e-06
#   1 SNES Function norm 4.931149839145e-16
#   0 SNES Function norm 1.845894082378e-06
#   1 SNES Function norm 4.693498260440e-16
#   0 SNES Function norm 1.816391436246e-06
#   1 SNES Function norm 4.790698919887e-16
#   0 SNES Function norm 1.787189003951e-06
#   1 SNES Function norm 4.773890700595e-16
#   0 SNES Function norm 1.758595282566e-06
#   1 SNES Function norm 4.744076831222e-16
#   0 SNES Function norm 1.730301056241e-06
#   1 SNES Function norm 4.891297359508e-16
#   0 SNES Function norm 1.702590103880e-06
#   1 SNES Function norm 5.066173872449e-16
#   0 SNES Function norm 1.675177258148e-06
#   1 SNES Function norm 4.794867180234e-16
#   0 SNES Function norm 1.648323545921e-06
#   1 SNES Function norm 4.655893681855e-16
#   0 SNES Function norm 1.621765957873e-06
#   1 SNES Function norm 4.928001348732e-16
#   0 SNES Function norm 1.595744576876e-06
#   1 SNES Function norm 4.646592541482e-16
#   0 SNES Function norm 1.570016812966e-06
#   1 SNES Function norm 4.841089511838e-16
#   0 SNES Function norm 1.544803469193e-06
#   1 SNES Function norm 4.942826257294e-16
#   0 SNES Function norm 1.519880771261e-06
#   1 SNES Function norm 4.939374115429e-16
#   0 SNES Function norm 1.495451778028e-06
#   1 SNES Function norm 4.697648840110e-16
#   0 SNES Function norm 1.471310051674e-06
#   1 SNES Function norm 5.040706152190e-16
#   0 SNES Function norm 1.447642320506e-06
#   1 SNES Function norm 4.721415218783e-16
#   0 SNES Function norm 1.424258123393e-06
#   1 SNES Function norm 4.874557114026e-16
#   0 SNES Function norm 1.401329155888e-06
#   1 SNES Function norm 4.813318703246e-16
#   0 SNES Function norm 1.378679682431e-06
#   1 SNES Function norm 4.726785089558e-16
#   0 SNES Function norm 1.356467562736e-06
#   1 SNES Function norm 4.872017895039e-16
#   0 SNES Function norm 1.334530632858e-06
#   1 SNES Function norm 4.788306294424e-16
#   0 SNES Function norm 1.313014016502e-06
#   1 SNES Function norm 4.770340956644e-16
#   0 SNES Function norm 1.291768061401e-06
#   1 SNES Function norm 4.597814988881e-16
#   0 SNES Function norm 1.270926168874e-06
#   1 SNES Function norm 4.803106799240e-16
#   0 SNES Function norm 1.250350216602e-06
#   1 SNES Function norm 4.796859216019e-16
#   0 SNES Function norm 1.230162821155e-06
#   1 SNES Function norm 4.894933704666e-16
#   0 SNES Function norm 1.210236487490e-06
#   1 SNES Function norm 4.802041956633e-16
#   0 SNES Function norm 1.190683904888e-06
#   1 SNES Function norm 4.930284837119e-16
#   0 SNES Function norm 1.171387375980e-06
#   1 SNES Function norm 4.731938506101e-16
#   0 SNES Function norm 1.152450457338e-06
#   1 SNES Function norm 4.992597467194e-16
#   0 SNES Function norm 1.133764479192e-06
#   1 SNES Function norm 4.776839103511e-16
#   0 SNES Function norm 1.115424596493e-06
#   1 SNES Function norm 4.751784916152e-16
#   0 SNES Function norm 1.097330462521e-06
#   1 SNES Function norm 4.720891253819e-16
#   0 SNES Function norm 1.079569500201e-06
#   1 SNES Function norm 4.633167456133e-16
#   0 SNES Function norm 1.062049038527e-06
#   1 SNES Function norm 4.835367691773e-16
#   0 SNES Function norm 1.044849381649e-06
#   1 SNES Function norm 4.818524153572e-16
#   0 SNES Function norm 1.027884940201e-06
#   1 SNES Function norm 4.740549487570e-16
#   0 SNES Function norm 1.011229468172e-06
#   1 SNES Function norm 4.994406297807e-16
#   0 SNES Function norm 9.948039034988e-07
#   1 SNES Function norm 4.923707600353e-16
#   0 SNES Function norm 9.786759735322e-07
#   1 SNES Function norm 4.735666240014e-16
#   0 SNES Function norm 9.627726384585e-07
#   1 SNES Function norm 4.875039727898e-16
#   0 SNES Function norm 9.471560799382e-07
#   1 SNES Function norm 4.945438695296e-16
#   0 SNES Function norm 9.317588110471e-07
#   1 SNES Function norm 4.857415642073e-16
#   0 SNES Function norm 9.166379121799e-07
#   1 SNES Function norm 4.952994167386e-16
#   0 SNES Function norm 9.017310173201e-07
#   1 SNES Function norm 4.801323466437e-16
#   0 SNES Function norm 8.870905158938e-07
#   1 SNES Function norm 4.897912230652e-16
#   0 SNES Function norm 8.726587628143e-07
#   1 SNES Function norm 4.869647326897e-16
#   0 SNES Function norm 8.584838348210e-07
#   1 SNES Function norm 4.831343191002e-16
#   0 SNES Function norm 8.445124397607e-07
#   1 SNES Function norm 4.751954005380e-16
#   0 SNES Function norm 8.307886890196e-07
#   1 SNES Function norm 4.926737092112e-16
#   0 SNES Function norm 8.172633050475e-07
#   1 SNES Function norm 4.868175955058e-16
#   0 SNES Function norm 8.039767520635e-07
#   1 SNES Function norm 4.761143631752e-16
#   0 SNES Function norm 7.908834583300e-07
#   1 SNES Function norm 4.901889330489e-16
#   0 SNES Function norm 7.780205319177e-07
#   1 SNES Function norm 4.762221102394e-16
#   0 SNES Function norm 7.653458198765e-07
#   1 SNES Function norm 4.876524162322e-16
#   0 SNES Function norm 7.528933472797e-07
#   1 SNES Function norm 4.950319387268e-16
#   0 SNES Function norm 7.406241117411e-07
#   1 SNES Function norm 4.965291353363e-16
#   0 SNES Function norm 7.285693054654e-07
#   1 SNES Function norm 4.820707815744e-16
#   0 SNES Function norm 7.166928360232e-07
#   1 SNES Function norm 4.984952156110e-16
#   0 SNES Function norm 7.050232856848e-07
#   1 SNES Function norm 4.905134372462e-16
#   0 SNES Function norm 6.935272516700e-07
#   1 SNES Function norm 4.931934337358e-16
#   0 SNES Function norm 6.822309170818e-07
#   1 SNES Function norm 4.852186354111e-16
#   0 SNES Function norm 6.711033585913e-07
#   1 SNES Function norm 4.868676850977e-16
#   0 SNES Function norm 6.601685561022e-07
#   1 SNES Function norm 4.774760527439e-16
#   0 SNES Function norm 6.493978757100e-07
#   1 SNES Function norm 4.686822199185e-16
#   0 SNES Function norm 6.388132715288e-07
#   1 SNES Function norm 4.836490585849e-16
#   0 SNES Function norm 6.283882214609e-07
#   1 SNES Function norm 4.783876560364e-16
#   0 SNES Function norm 6.181428213417e-07
#   1 SNES Function norm 4.833363252730e-16
#   0 SNES Function norm 6.080524965050e-07
#   1 SNES Function norm 4.946387102668e-16
#   0 SNES Function norm 5.981356358343e-07
#   1 SNES Function norm 5.035929436201e-16
#   0 SNES Function norm 5.883694628322e-07
#   1 SNES Function norm 4.874405487858e-16
#   0 SNES Function norm 5.787707985248e-07
#   1 SNES Function norm 4.797009121227e-16
#   0 SNES Function norm 5.693185279049e-07
#   1 SNES Function norm 4.778093460686e-16
#   0 SNES Function norm 5.600280293703e-07
#   1 SNES Function norm 4.941135073003e-16
#   0 SNES Function norm 5.508797230751e-07
#   1 SNES Function norm 4.984403910620e-16
#   0 SNES Function norm 5.418876651250e-07
#   1 SNES Function norm 4.709940365806e-16
#   0 SNES Function norm 5.330336919250e-07
#   1 SNES Function norm 4.796163292124e-16
#   0 SNES Function norm 5.243306427012e-07
#   1 SNES Function norm 4.953089709303e-16
#   0 SNES Function norm 5.157616666151e-07
#   1 SNES Function norm 4.850328211589e-16
#   0 SNES Function norm 5.073384844824e-07
#   1 SNES Function norm 4.831825408531e-16
#   0 SNES Function norm 4.990454553642e-07
#   1 SNES Function norm 4.991025121658e-16
#   0 SNES Function norm 4.908932772304e-07
#   1 SNES Function norm 4.829741142885e-16
#   0 SNES Function norm 4.828674265446e-07
#   1 SNES Function norm 4.868769029324e-16
#   0 SNES Function norm 4.749776598078e-07
#   1 SNES Function norm 4.871645624818e-16
#   0 SNES Function norm 4.672104889199e-07
#   1 SNES Function norm 4.711746413065e-16
#   0 SNES Function norm 4.595748060183e-07
#   1 SNES Function norm 5.070767885101e-16
#   0 SNES Function norm 4.520580801489e-07
#   1 SNES Function norm 4.701598299275e-16
#   0 SNES Function norm 4.446684092073e-07
#   1 SNES Function norm 4.964692970289e-16
#   0 SNES Function norm 4.373941480379e-07
#   1 SNES Function norm 4.824554231070e-16
#   0 SNES Function norm 4.302426672535e-07
#   1 SNES Function norm 4.550434942398e-16
#   0 SNES Function norm 4.232031388221e-07
#   1 SNES Function norm 4.916978595076e-16
#   0 SNES Function norm 4.162822682904e-07
#   1 SNES Function norm 4.816016650977e-16
#   0 SNES Function norm 4.094699808150e-07
#   1 SNES Function norm 4.773667378676e-16
#   0 SNES Function norm 4.027723742868e-07
#   1 SNES Function norm 5.022095593934e-16
#   0 SNES Function norm 3.961800711577e-07
#   1 SNES Function norm 4.620510350036e-16
#   0 SNES Function norm 3.896986106979e-07
#   1 SNES Function norm 4.693598539861e-16
#   0 SNES Function norm 3.833192613346e-07
#   1 SNES Function norm 4.689129598679e-16
#   0 SNES Function norm 3.770470497509e-07
#   1 SNES Function norm 4.849271141817e-16
#   0 SNES Function norm 3.708738440095e-07
#   1 SNES Function norm 4.954590973540e-16
#   0 SNES Function norm 3.648041994064e-07
#   1 SNES Function norm 4.784443908816e-16
#   0 SNES Function norm 3.588305397257e-07
#   1 SNES Function norm 4.759445552068e-16
#   0 SNES Function norm 3.529569890200e-07
#   1 SNES Function norm 4.905703124519e-16
#   0 SNES Function norm 3.471764848991e-07
#   1 SNES Function norm 4.803983801657e-16
#   0 SNES Function norm 3.414927569331e-07
#   1 SNES Function norm 4.883393502306e-16
#   0 SNES Function norm 3.358992183947e-07
#   1 SNES Function norm 4.804526992573e-16
#   0 SNES Function norm 3.303992389900e-07
#   1 SNES Function norm 4.887124438799e-16
#   0 SNES Function norm 3.249866718889e-07
#   1 SNES Function norm 4.897332568563e-16
#   0 SNES Function norm 3.196645555554e-07
#   1 SNES Function norm 4.883888968708e-16
#   0 SNES Function norm 3.144271531972e-07
#   1 SNES Function norm 4.827020401606e-16
#   0 SNES Function norm 3.092772016371e-07
#   1 SNES Function norm 4.919425090601e-16
#   0 SNES Function norm 3.042093403005e-07
#   1 SNES Function norm 4.853557851999e-16
#   0 SNES Function norm 2.992260333170e-07
#   1 SNES Function norm 4.724307936932e-16
#   0 SNES Function norm 2.943222677290e-07
#   1 SNES Function norm 4.853571217153e-16
#   0 SNES Function norm 2.895002572125e-07
#   1 SNES Function norm 5.017268052819e-16
#   0 SNES Function norm 2.847553163124e-07
#   1 SNES Function norm 4.952370409899e-16
#   0 SNES Function norm 2.800894229472e-07
#   1 SNES Function norm 4.763129343084e-16
#   0 SNES Function norm 2.754981993515e-07
#   1 SNES Function norm 4.797787351060e-16
#   0 SNES Function norm 2.709834094577e-07
#   1 SNES Function norm 4.883169521755e-16
#   0 SNES Function norm 2.665409581014e-07
#   1 SNES Function norm 4.766376397760e-16
#   0 SNES Function norm 2.621724151058e-07
#   1 SNES Function norm 4.873162125447e-16
#   0 SNES Function norm 2.578739485686e-07
#   1 SNES Function norm 4.897082705933e-16
#   0 SNES Function norm 2.536469496233e-07
#   1 SNES Function norm 4.901221132385e-16
#   0 SNES Function norm 2.494878308864e-07
#   1 SNES Function norm 5.002476359288e-16
#   0 SNES Function norm 2.453978236507e-07
#   1 SNES Function norm 4.760091025155e-16
#   0 SNES Function norm 2.413735629711e-07
#   1 SNES Function norm 4.755643710170e-16
#   0 SNES Function norm 2.374161383526e-07
#   1 SNES Function norm 4.677435301012e-16
#   0 SNES Function norm 2.335223899929e-07
#   1 SNES Function norm 4.988503814296e-16
#   0 SNES Function norm 2.296932777044e-07
#   1 SNES Function norm 4.810161967251e-16
#   0 SNES Function norm 2.259258347600e-07
#   1 SNES Function norm 4.813019932850e-16
#   0 SNES Function norm 2.222209003627e-07
#   1 SNES Function norm 5.125790806874e-16
#   0 SNES Function norm 2.185756889369e-07
#   1 SNES Function norm 5.036150282629e-16
#   0 SNES Function norm 2.149909308435e-07
#   1 SNES Function norm 4.965740811592e-16
#   0 SNES Function norm 2.114640068497e-07
#   1 SNES Function norm 4.669795055920e-16
#   0 SNES Function norm 2.079955491504e-07
#   1 SNES Function norm 4.827642968232e-16
#   0 SNES Function norm 2.045830951441e-07
#   1 SNES Function norm 4.895038599076e-16
#   0 SNES Function norm 2.012271868516e-07
#   1 SNES Function norm 4.953759024156e-16
#   0 SNES Function norm 1.979255060227e-07
#   1 SNES Function norm 4.811777994338e-16
#   0 SNES Function norm 1.946785146056e-07
#   1 SNES Function norm 4.777285892681e-16
#   0 SNES Function norm 1.914840297629e-07
#   1 SNES Function norm 5.063538316449e-16
#   0 SNES Function norm 1.883424386570e-07
#   1 SNES Function norm 4.738533951969e-16
#   0 SNES Function norm 1.852516863064e-07
#   1 SNES Function norm 4.779822963997e-16
#   0 SNES Function norm 1.822120918616e-07
#   1 SNES Function norm 4.729571096471e-16
#   0 SNES Function norm 1.792217188472e-07
#   1 SNES Function norm 4.819794384791e-16
#   0 SNES Function norm 1.762808260888e-07
#   1 SNES Function norm 4.864046804941e-16
#   0 SNES Function norm 1.733875865419e-07
#   1 SNES Function norm 4.745734365433e-16
#   0 SNES Function norm 1.705422057753e-07
#   1 SNES Function norm 4.616793264613e-16
#   0 SNES Function norm 1.677429593818e-07
#   1 SNES Function norm 4.932132112695e-16
#   0 SNES Function norm 1.649900018803e-07
#   1 SNES Function norm 5.023799895745e-16
#   0 SNES Function norm 1.622817082962e-07
#   1 SNES Function norm 4.761512693539e-16
#   0 SNES Function norm 1.596181843788e-07
#   1 SNES Function norm 4.794482214993e-16
#   0 SNES Function norm 1.569979011077e-07
#   1 SNES Function norm 4.943324864261e-16
#   0 SNES Function norm 1.544209183419e-07
#   1 SNES Function norm 4.694832766870e-16
#   0 SNES Function norm 1.518857955830e-07
#   1 SNES Function norm 4.983710341381e-16
#   0 SNES Function norm 1.493925535634e-07
#   1 SNES Function norm 4.916143108082e-16
#   0 SNES Function norm 1.469398346785e-07
#   1 SNES Function norm 4.799863837546e-16
#   0 SNES Function norm 1.445276237910e-07
#   1 SNES Function norm 4.822308767799e-16
#   0 SNES Function norm 1.421546380450e-07
#   1 SNES Function norm 4.760090161318e-16
#   0 SNES Function norm 1.398208365579e-07
#   1 SNES Function norm 4.906976800469e-16
#   0 SNES Function norm 1.375250004184e-07
#   1 SNES Function norm 4.856573693754e-16
#   0 SNES Function norm 1.352670688365e-07
#   1 SNES Function norm 4.666115428577e-16
#   0 SNES Function norm 1.330458833327e-07
#   1 SNES Function norm 4.962850486291e-16
#   0 SNES Function norm 1.308613628204e-07
#   1 SNES Function norm 4.815590057591e-16
#   0 SNES Function norm 1.287124100252e-07
#   1 SNES Function norm 4.655920433691e-16
#   0 SNES Function norm 1.265989218200e-07
#   1 SNES Function norm 4.774876006118e-16
#   0 SNES Function norm 1.245198587483e-07
#   1 SNES Function norm 4.999405148259e-16
#   0 SNES Function norm 1.224751024738e-07
#   1 SNES Function norm 5.054321807018e-16
#   0 SNES Function norm 1.204636628191e-07
#   1 SNES Function norm 4.852725224412e-16
#   0 SNES Function norm 1.184854101540e-07
#   1 SNES Function norm 5.005723438319e-16
#   0 SNES Function norm 1.165394006695e-07
#   1 SNES Function norm 4.685310817401e-16
#   0 SNES Function norm 1.146254952684e-07
#   1 SNES Function norm 4.869465370260e-16
#   0 SNES Function norm 1.127427943637e-07
#   1 SNES Function norm 5.072612524151e-16
#   0 SNES Function norm 1.108911494622e-07
#   1 SNES Function norm 4.778821622430e-16
#   0 SNES Function norm 1.090697028063e-07
#   1 SNES Function norm 4.868773122202e-16
#   0 SNES Function norm 1.072782989603e-07
#   1 SNES Function norm 5.028619296442e-16
#   0 SNES Function norm 1.055161188451e-07
#   1 SNES Function norm 4.701412999853e-16
#   0 SNES Function norm 1.037830022878e-07
#   1 SNES Function norm 4.741078260602e-16
#   0 SNES Function norm 1.020781648105e-07
#   1 SNES Function norm 4.876151994339e-16
#   0 SNES Function norm 1.004014439406e-07
#   1 SNES Function norm 4.916537646543e-16
#   0 SNES Function norm 9.875208781883e-08
#   1 SNES Function norm 4.790490034461e-16
#   0 SNES Function norm 9.712993248948e-08
#   1 SNES Function norm 5.013109679351e-16
#   0 SNES Function norm 9.553425734784e-08
#   1 SNES Function norm 4.975868101868e-16
#   0 SNES Function norm 9.396489466791e-08
#   1 SNES Function norm 4.844574685089e-16
#   0 SNES Function norm 9.242115825703e-08
#   1 SNES Function norm 4.819332855918e-16
#   0 SNES Function norm 9.090287486208e-08
#   1 SNES Function norm 4.836455732699e-16
#   0 SNES Function norm 8.940938965998e-08
#   1 SNES Function norm 4.853561895650e-16
#   0 SNES Function norm 8.794052670804e-08
#   1 SNES Function norm 5.017138397433e-16
#   0 SNES Function norm 8.649566077382e-08
#   1 SNES Function norm 5.227065029277e-16
#   0 SNES Function norm 8.507461378245e-08
#   1 SNES Function norm 4.803813257202e-16
#   0 SNES Function norm 8.367678774340e-08
#   1 SNES Function norm 4.745986040615e-16
#   0 SNES Function norm 8.230200150948e-08
#   1 SNES Function norm 5.096198220095e-16
#   0 SNES Function norm 8.094968887745e-08
#   1 SNES Function norm 4.790331442558e-16
#   0 SNES Function norm 7.961966211374e-08
#   1 SNES Function norm 4.944130766684e-16
#   0 SNES Function norm 7.831138099832e-08
#   1 SNES Function norm 4.880146327248e-16
#   0 SNES Function norm 7.702465942310e-08
#   1 SNES Function norm 4.895200780555e-16
#   0 SNES Function norm 7.575898057947e-08
#   1 SNES Function norm 4.900364796570e-16
#   0 SNES Function norm 7.451415711585e-08
#   1 SNES Function norm 4.766304108495e-16
#   0 SNES Function norm 7.328969458022e-08
#   1 SNES Function norm 4.923401694353e-16
#   0 SNES Function norm 7.208540702349e-08
#   1 SNES Function norm 4.939914688759e-16
#   0 SNES Function norm 7.090082270555e-08
#   1 SNES Function norm 4.864626555939e-16
#   0 SNES Function norm 6.973575266599e-08
#   1 SNES Function norm 4.933424228306e-16
#   0 SNES Function norm 6.858974982747e-08
#   1 SNES Function norm 4.778034285113e-16
#   0 SNES Function norm 6.746262261133e-08
#   1 SNES Function norm 4.744732851573e-16
#   0 SNES Function norm 6.635394680924e-08
#   1 SNES Function norm 4.814044547514e-16
#   0 SNES Function norm 6.526352914385e-08
#   1 SNES Function norm 4.869873054354e-16
#   0 SNES Function norm 6.419096540492e-08
#   1 SNES Function norm 4.974426999037e-16
#   0 SNES Function norm 6.313606488829e-08
#   1 SNES Function norm 4.637220395012e-16
#   0 SNES Function norm 6.209843827547e-08
#   1 SNES Function norm 4.936552137766e-16
#   0 SNES Function norm 6.107790021114e-08
#   1 SNES Function norm 4.895325481896e-16
#   0 SNES Function norm 6.007407404432e-08
#   1 SNES Function norm 4.986434835276e-16
#   0 SNES Function norm 5.908678010897e-08
#   1 SNES Function norm 4.948912788970e-16
#   0 SNES Function norm 5.811565634351e-08
#   1 SNES Function norm 4.740869295999e-16
#   0 SNES Function norm 5.716052474482e-08
#   1 SNES Function norm 4.916360697485e-16
#   0 SNES Function norm 5.622103926683e-08
#   1 SNES Function norm 4.814379293846e-16
#   0 SNES Function norm 5.529702302469e-08
#   1 SNES Function norm 4.718505440336e-16
#   0 SNES Function norm 5.438814828488e-08
#   1 SNES Function norm 4.732934546095e-16
#   0 SNES Function norm 5.349423404640e-08
#   1 SNES Function norm 4.822765699306e-16
#   0 SNES Function norm 5.261497335564e-08
#   1 SNES Function norm 4.972975665806e-16
#   0 SNES Function norm 5.175018273944e-08
#   1 SNES Function norm 4.829836178440e-16
#   0 SNES Function norm 5.089957210429e-08
#   1 SNES Function norm 4.976453121427e-16
#   0 SNES Function norm 5.006295803592e-08
#   1 SNES Function norm 4.780282367446e-16
#   0 SNES Function norm 4.924006395646e-08
#   1 SNES Function norm 4.830585084858e-16
#   0 SNES Function norm 4.843071000816e-08
#   1 SNES Function norm 4.889204937444e-16
#   0 SNES Function norm 4.763463130479e-08
#   1 SNES Function norm 4.880540917548e-16
#   0 SNES Function norm 4.685164910801e-08
#   1 SNES Function norm 4.721996951823e-16
#   0 SNES Function norm 4.608151295865e-08
#   1 SNES Function norm 4.896723844933e-16
#   0 SNES Function norm 4.532404452358e-08
#   1 SNES Function norm 4.575874218001e-16
#   0 SNES Function norm 4.457900695660e-08
#   1 SNES Function norm 5.073287914598e-16
#   0 SNES Function norm 4.384622161366e-08
#   1 SNES Function norm 4.819955091068e-16
#   0 SNES Function norm 4.312546460362e-08
#   1 SNES Function norm 4.976752485506e-16
#   0 SNES Function norm 4.241656015772e-08
#   1 SNES Function norm 4.823020606408e-16
#   0 SNES Function norm 4.171929259106e-08
#   1 SNES Function norm 4.983637130750e-16
#   0 SNES Function norm 4.103349112504e-08
#   1 SNES Function norm 4.938363427195e-16
#   0 SNES Function norm 4.035894908935e-08
#   1 SNES Function norm 4.797925121450e-16
#   0 SNES Function norm 3.969549860773e-08
#   1 SNES Function norm 4.798904795203e-16
#   0 SNES Function norm 3.904294076331e-08
#   1 SNES Function norm 5.108790186016e-16
#   0 SNES Function norm 3.840111530686e-08
#   1 SNES Function norm 4.637761616031e-16
#   0 SNES Function norm 3.776982469926e-08
#   1 SNES Function norm 4.854489547423e-16
#   0 SNES Function norm 3.714891958005e-08
#   1 SNES Function norm 4.964364772468e-16
#   0 SNES Function norm 3.653820542493e-08
#   1 SNES Function norm 4.985214527282e-16
#   0 SNES Function norm 3.593753710028e-08
#   1 SNES Function norm 4.881479563143e-16
#   0 SNES Function norm 3.534673132002e-08
#   1 SNES Function norm 4.914907968906e-16
#   0 SNES Function norm 3.476564034484e-08
#   1 SNES Function norm 4.830251731104e-16
#   0 SNES Function norm 3.419409369536e-08
#   1 SNES Function norm 5.049191827238e-16
#   0 SNES Function norm 3.363194368540e-08
#   1 SNES Function norm 4.903510227291e-16
#   0 SNES Function norm 3.307902713248e-08
#   1 SNES Function norm 4.785820960170e-16
#   0 SNES Function norm 3.253520251158e-08
#   1 SNES Function norm 4.981876240054e-16
#   0 SNES Function norm 3.200030968420e-08
#   1 SNES Function norm 4.826290046790e-16
#   0 SNES Function norm 3.147421270642e-08
#   1 SNES Function norm 4.842055957653e-16
#   0 SNES Function norm 3.095675634533e-08
#   1 SNES Function norm 4.824774004512e-16
#   0 SNES Function norm 3.044780956031e-08
#   1 SNES Function norm 4.827240948041e-16
#   0 SNES Function norm 2.994722266628e-08
#   1 SNES Function norm 4.581929892967e-16
#   0 SNES Function norm 2.945486642566e-08
#   1 SNES Function norm 4.801041549587e-16
#   0 SNES Function norm 2.897059952786e-08
#   1 SNES Function norm 4.978641023612e-16
#   0 SNES Function norm 2.849429433640e-08
#   1 SNES Function norm 4.800419311645e-16
#   0 SNES Function norm 2.802581473881e-08
#   1 SNES Function norm 4.964718166998e-16
#   0 SNES Function norm 2.756503753642e-08
#   1 SNES Function norm 5.000038263110e-16
#   0 SNES Function norm 2.711183145428e-08
#   1 SNES Function norm 4.785904865067e-16
#   0 SNES Function norm 2.666607618393e-08
#   1 SNES Function norm 5.005249441670e-16
#   0 SNES Function norm 2.622764612249e-08
#   1 SNES Function norm 4.812949592091e-16
#   0 SNES Function norm 2.579642339020e-08
#   1 SNES Function norm 4.725992273759e-16
#   0 SNES Function norm 2.537228743164e-08
#   1 SNES Function norm 5.029801339110e-16
#   0 SNES Function norm 2.495512438903e-08
#   1 SNES Function norm 4.950833195466e-16
#   0 SNES Function norm 2.454481651874e-08
#   1 SNES Function norm 4.925943545246e-16
#   0 SNES Function norm 2.414125421455e-08
#   1 SNES Function norm 4.826670732977e-16
#   0 SNES Function norm 2.374432512520e-08
#   1 SNES Function norm 4.735963537100e-16
#   0 SNES Function norm 2.335392014468e-08
#   1 SNES Function norm 4.894433192886e-16
#   0 SNES Function norm 2.296993330835e-08
#   1 SNES Function norm 5.094225805320e-16
#   0 SNES Function norm 2.259225695811e-08
#   1 SNES Function norm 4.829500922454e-16
#   0 SNES Function norm 2.222079094960e-08
#   1 SNES Function norm 4.847919346550e-16
#   0 SNES Function norm 2.185542845375e-08
#   1 SNES Function norm 4.958726256196e-16
#   0 SNES Function norm 2.149607453665e-08
#   1 SNES Function norm 4.964563048960e-16
#   0 SNES Function norm 2.114262559413e-08
#   1 SNES Function norm 4.721413888162e-16
#   0 SNES Function norm 2.079498840808e-08
#   1 SNES Function norm 5.005664224519e-16
#   0 SNES Function norm 2.045306527598e-08
#   1 SNES Function norm 4.867899221457e-16
#   0 SNES Function norm 2.011676254059e-08
#   1 SNES Function norm 5.196032434659e-16
#   0 SNES Function norm 1.978598905137e-08
#   1 SNES Function norm 5.039633091906e-16
#   0 SNES Function norm 1.946065285946e-08
#   1 SNES Function norm 5.029004237503e-16
#   0 SNES Function norm 1.914066409358e-08
#   1 SNES Function norm 4.810176338161e-16
#   0 SNES Function norm 1.882593726910e-08
#   1 SNES Function norm 4.700865305855e-16
#   0 SNES Function norm 1.851638286414e-08
#   1 SNES Function norm 4.820599757024e-16
#   0 SNES Function norm 1.821191856345e-08
#   1 SNES Function norm 4.910202821444e-16
#   0 SNES Function norm 1.791245864202e-08
#   1 SNES Function norm 4.792422211980e-16
#   0 SNES Function norm 1.761792239882e-08
#   1 SNES Function norm 4.805328834330e-16
#   0 SNES Function norm 1.732822750694e-08
#   1 SNES Function norm 4.944720862867e-16
#   0 SNES Function norm 1.704329673405e-08
#   1 SNES Function norm 4.863644372324e-16
#   0 SNES Function norm 1.676304813258e-08
#   1 SNES Function norm 4.881883463909e-16
#   0 SNES Function norm 1.648740877004e-08
#   1 SNES Function norm 5.012870157409e-16
#   0 SNES Function norm 1.621629970052e-08
#   1 SNES Function norm 4.903504470377e-16
#   0 SNES Function norm 1.594964798653e-08
#   1 SNES Function norm 4.985043233935e-16
#   0 SNES Function norm 1.568738146545e-08
#   1 SNES Function norm 4.802396417047e-16
#   0 SNES Function norm 1.542942428362e-08
#   1 SNES Function norm 4.618087154958e-16
#   0 SNES Function norm 1.517571118981e-08
#   1 SNES Function norm 4.929347822893e-16
#   0 SNES Function norm 1.492616614107e-08
#   1 SNES Function norm 4.860041073595e-16
#   0 SNES Function norm 1.468072631435e-08
#   1 SNES Function norm 4.782862186043e-16
#   0 SNES Function norm 1.443932039767e-08
#   1 SNES Function norm 4.738462120235e-16
#   0 SNES Function norm 1.420188422856e-08
#   1 SNES Function norm 4.873652182467e-16
#   0 SNES Function norm 1.396835126984e-08
#   1 SNES Function norm 4.807766232108e-16
#   0 SNES Function norm 1.373865776215e-08
#   1 SNES Function norm 4.861049322037e-16
#   0 SNES Function norm 1.351274132898e-08
#   1 SNES Function norm 4.646687063427e-16
#   0 SNES Function norm 1.329053908440e-08
#   1 SNES Function norm 4.838773258861e-16
#   0 SNES Function norm 1.307198943671e-08
#   1 SNES Function norm 5.073329448434e-16
#   0 SNES Function norm 1.285703463073e-08
#   1 SNES Function norm 4.649652332403e-16
#   0 SNES Function norm 1.264561195234e-08
#   1 SNES Function norm 5.002405760403e-16
#   0 SNES Function norm 1.243766822364e-08
#   1 SNES Function norm 5.061253638903e-16
#   0 SNES Function norm 1.223313957826e-08
#   1 SNES Function norm 4.634686365036e-16
#   0 SNES Function norm 1.203197879739e-08
#   1 SNES Function norm 4.859042995420e-16
# ...
#   0 SNES Function norm 5.428449289526e-09
#   1 SNES Function norm 4.861667953464e-16
#   0 SNES Function norm 5.339176627114e-09
#   1 SNES Function norm 4.772645099029e-16
#   0 SNES Function norm 5.251371934584e-09
#   1 SNES Function norm 4.820105189354e-16
#   0 SNES Function norm 5.165010958056e-09
#   1 SNES Function norm 4.869506175690e-16
#   0 SNES Function norm 5.080070480035e-09
#   1 SNES Function norm 4.996954731298e-16
#   0 SNES Function norm 4.996526681985e-09
#   1 SNES Function norm 4.653751949971e-16
#   0 SNES Function norm 4.914356763046e-09
#   1 SNES Function norm 4.677732168804e-16
#   0 SNES Function norm 4.833538009631e-09
#   1 SNES Function norm 4.713062622176e-16
#   0 SNES Function norm 4.754048161978e-09
#   1 SNES Function norm 4.796915824864e-16
#   0 SNES Function norm 4.675866521819e-09
#   1 SNES Function norm 4.832333485488e-16
#   0 SNES Function norm 4.598968341774e-09
#   1 SNES Function norm 4.922407874834e-16
#   0 SNES Function norm 4.523337183041e-09
#   1 SNES Function norm 4.929363308548e-16
#   0 SNES Function norm 4.448947893993e-09
#   1 SNES Function norm 4.855140086909e-16
#   0 SNES Function norm 4.375783567278e-09
#   1 SNES Function norm 4.885035972344e-16
#   0 SNES Function norm 4.303820520873e-09
#   1 SNES Function norm 4.776170213798e-16
#   0 SNES Function norm 4.233042759021e-09
#   1 SNES Function norm 4.774969186544e-16
#   0 SNES Function norm 4.163427463273e-09
#   1 SNES Function norm 4.854380220768e-16
#   0 SNES Function norm 4.094958138441e-09
#   1 SNES Function norm 4.790063228145e-16
#   0 SNES Function norm 4.027613820432e-09
#   1 SNES Function norm 4.898359006915e-16
#   0 SNES Function norm 3.961377552904e-09
#   1 SNES Function norm 4.954816546778e-16
#   0 SNES Function norm 3.896230392165e-09
#   1 SNES Function norm 4.722143815314e-16
#   0 SNES Function norm 3.832154320064e-09
#   1 SNES Function norm 4.933806712022e-16
#   0 SNES Function norm 3.769132777365e-09
#   1 SNES Function norm 4.838464772904e-16
#   0 SNES Function norm 3.707146339075e-09
#   1 SNES Function norm 4.913815029920e-16
#   0 SNES Function norm 3.646180667743e-09
#   1 SNES Function norm 4.896001547719e-16
#   0 SNES Function norm 3.586216204785e-09
#   1 SNES Function norm 5.087669729410e-16
#   0 SNES Function norm 3.527239712296e-09
#   1 SNES Function norm 4.722173898647e-16
#   0 SNES Function norm 3.469229802558e-09
#   1 SNES Function norm 4.772393050833e-16
#   0 SNES Function norm 3.412178644418e-09
#   1 SNES Function norm 4.859038647797e-16
#   0 SNES Function norm 3.356060255043e-09
#   1 SNES Function norm 4.795411952751e-16
#   0 SNES Function norm 3.300870754997e-09
#   1 SNES Function norm 4.979033920971e-16
#   0 SNES Function norm 3.246582460069e-09
#   1 SNES Function norm 4.836274758260e-16
#   0 SNES Function norm 3.193192515744e-09
#   1 SNES Function norm 4.816495588363e-16
#   0 SNES Function norm 3.140676858005e-09
#   1 SNES Function norm 4.882296564751e-16
#   0 SNES Function norm 3.089026679798e-09
#   1 SNES Function norm 4.816572773935e-16
#   0 SNES Function norm 3.038225324454e-09
#   1 SNES Function norm 4.797345373879e-16
#   0 SNES Function norm 2.988259119143e-09
#   1 SNES Function norm 4.892934723268e-16
#   0 SNES Function norm 2.939115741904e-09
#   1 SNES Function norm 5.022164512988e-16
#   0 SNES Function norm 2.890778691130e-09
#   1 SNES Function norm 4.871752790880e-16
#   0 SNES Function norm 2.843239186428e-09
#   1 SNES Function norm 4.746339803328e-16
#   0 SNES Function norm 2.796477705689e-09
#   1 SNES Function norm 5.132609007399e-16
#   0 SNES Function norm 2.750490282224e-09
#   1 SNES Function norm 4.935002890521e-16
#   0 SNES Function norm 2.705253085587e-09
#   1 SNES Function norm 4.821210060858e-16
#   0 SNES Function norm 2.660766686118e-09
#   1 SNES Function norm 4.874100016581e-16
#   0 SNES Function norm 2.617004300611e-09
#   1 SNES Function norm 4.696812685245e-16
#   0 SNES Function norm 2.573969566692e-09
#   1 SNES Function norm 4.804265138494e-16
#   0 SNES Function norm 2.531634651698e-09
#   1 SNES Function norm 4.610303970875e-16
#   0 SNES Function norm 2.490003768286e-09
#   1 SNES Function norm 4.971663174419e-16
#   0 SNES Function norm 2.449049700621e-09
#   1 SNES Function norm 4.923134062461e-16
#   0 SNES Function norm 2.408776717811e-09
#   1 SNES Function norm 4.901055021606e-16
#   0 SNES Function norm 2.369159163934e-09
#   1 SNES Function norm 4.754217936358e-16
#   0 SNES Function norm 2.330199058258e-09
#   1 SNES Function norm 5.080252909059e-16
#   0 SNES Function norm 2.291874437728e-09
#   1 SNES Function norm 4.774390301871e-16
#   0 SNES Function norm 2.254185380630e-09
#   1 SNES Function norm 4.841141640849e-16
#   0 SNES Function norm 2.217110217662e-09
#   1 SNES Function norm 5.114416605739e-16
#   0 SNES Function norm 2.180650979318e-09
#   1 SNES Function norm 4.834018657203e-16
#   0 SNES Function norm 2.144785830359e-09
#   1 SNES Function norm 4.885381210445e-16
#   0 SNES Function norm 2.109514787858e-09
#   1 SNES Function norm 4.709260512189e-16
#   0 SNES Function norm 2.074820203914e-09
#   1 SNES Function norm 4.944847488426e-16
#   0 SNES Function norm 2.040699781823e-09
#   1 SNES Function norm 4.868008791743e-16
#   0 SNES Function norm 2.007136883815e-09
#   1 SNES Function norm 4.863923981431e-16
#   0 SNES Function norm 1.974129474021e-09
#   1 SNES Function norm 4.752667371111e-16
#   0 SNES Function norm 1.941661479036e-09
#   1 SNES Function norm 5.151839531393e-16
#   0 SNES Function norm 1.909730218259e-09
#   1 SNES Function norm 4.935540121230e-16
#   0 SNES Function norm 1.878323090902e-09
#   1 SNES Function norm 4.852882272292e-16
#   0 SNES Function norm 1.847430930329e-09
#   1 SNES Function norm 4.847301450855e-16
#   0 SNES Function norm 1.817050038691e-09
#   1 SNES Function norm 4.965445110782e-16
#   0 SNES Function norm 1.787165099755e-09
#   1 SNES Function norm 4.901593911411e-16
#   0 SNES Function norm 1.757775629504e-09
#   1 SNES Function norm 4.853544516345e-16
#   0 SNES Function norm 1.728864830622e-09
#   1 SNES Function norm 4.939650418128e-16
#   0 SNES Function norm 1.700434899417e-09
#   1 SNES Function norm 4.855695123622e-16
#   0 SNES Function norm 1.672466836658e-09
#   1 SNES Function norm 4.748680965658e-16
#   0 SNES Function norm 1.644964184455e-09
#   1 SNES Function norm 4.901242981352e-16
#   0 SNES Function norm 1.617908368678e-09
#   1 SNES Function norm 4.895391341802e-16
#   0 SNES Function norm 1.591303565370e-09
#   1 SNES Function norm 4.977033110349e-16
#   0 SNES Function norm 1.565129386579e-09
#   1 SNES Function norm 4.881126843382e-16
#   0 SNES Function norm 1.539392892634e-09
#   1 SNES Function norm 4.651955410441e-16
#   0 SNES Function norm 1.514073407893e-09
#   1 SNES Function norm 4.783380229759e-16
#   0 SNES Function norm 1.489174645707e-09
#   1 SNES Function norm 4.896027643699e-16
#   0 SNES Function norm 1.464682827921e-09
#   1 SNES Function norm 4.652621687973e-16
#   0 SNES Function norm 1.440594773209e-09
#   1 SNES Function norm 4.867254358348e-16
#   0 SNES Function norm 1.416903474795e-09
#   1 SNES Function norm 4.656044074221e-16
#   0 SNES Function norm 1.393600291506e-09
#   1 SNES Function norm 4.896206135385e-16
#   0 SNES Function norm 1.370681496239e-09
#   1 SNES Function norm 4.896905676481e-16
#   0 SNES Function norm 1.348139176875e-09
#   1 SNES Function norm 4.950828063422e-16
#   0 SNES Function norm 1.325967658812e-09
#   1 SNES Function norm 4.848773218405e-16
#   0 SNES Function norm 1.304161358744e-09
#   1 SNES Function norm 4.773319177119e-16
#   0 SNES Function norm 1.282711871470e-09
#   1 SNES Function norm 5.062153184505e-16
#   0 SNES Function norm 1.261617873763e-09
#   1 SNES Function norm 4.636759642637e-16
#   0 SNES Function norm 1.240868371668e-09
#   1 SNES Function norm 4.899024136369e-16
#   0 SNES Function norm 1.220461271859e-09
#   1 SNES Function norm 4.862152374922e-16
#   0 SNES Function norm 1.200389373849e-09
#   1 SNES Function norm 4.783639260933e-16
#   0 SNES Function norm 1.180648040336e-09
#   1 SNES Function norm 4.741044828653e-16
#   0 SNES Function norm 1.161231153453e-09
#   1 SNES Function norm 4.740380734058e-16
#   0 SNES Function norm 1.142133169169e-09
#   1 SNES Function norm 4.868606830555e-16
#   0 SNES Function norm 1.123349463865e-09
#   1 SNES Function norm 4.672500746241e-16
#   0 SNES Function norm 1.104876054477e-09
#   1 SNES Function norm 5.108264509274e-16
#   0 SNES Function norm 1.086703223506e-09
#   1 SNES Function norm 4.713755023744e-16
#   0 SNES Function norm 1.068833118392e-09
#   1 SNES Function norm 4.860769455345e-16
#   0 SNES Function norm 1.051253897432e-09
#   1 SNES Function norm 4.661209039811e-16
#   0 SNES Function norm 1.033965828649e-09
#   1 SNES Function norm 4.844350202990e-16
#   0 SNES Function norm 1.016960064391e-09
#   1 SNES Function norm 4.764008530529e-16
#   0 SNES Function norm 1.000236379871e-09
#   1 SNES Function norm 4.890476192616e-16
#   0 SNES Function norm 9.837854625576e-10
#   1 SNES Function norm 5.119146088296e-16
#   0 SNES Function norm 9.676062284528e-10
#   1 SNES Function norm 4.810282190531e-16
#   0 SNES Function norm 9.516933875388e-10
#   1 SNES Function norm 4.806495494470e-16
#   0 SNES Function norm 9.360415701424e-10
#   1 SNES Function norm 4.825754107727e-16
#   0 SNES Function norm 9.206472270134e-10
#   1 SNES Function norm 4.727493161703e-16
#   0 SNES Function norm 9.055064945240e-10
#   1 SNES Function norm 4.987860304594e-16
#   0 SNES Function norm 8.906143731129e-10
#   1 SNES Function norm 4.590477931531e-16
#   0 SNES Function norm 8.759671005394e-10
#   1 SNES Function norm 4.865675887618e-16
#   0 SNES Function norm 8.615609764352e-10
#   1 SNES Function norm 4.869898209134e-16
#   0 SNES Function norm 8.473918399022e-10
#   1 SNES Function norm 4.827874534152e-16
#   0 SNES Function norm 8.334551844469e-10
#   1 SNES Function norm 4.962671578599e-16
#   0 SNES Function norm 8.197487529631e-10
#   1 SNES Function norm 4.774847822600e-16
#   0 SNES Function norm 8.062667212160e-10
#   1 SNES Function norm 4.947651529692e-16
#   0 SNES Function norm 7.930069644160e-10
#   1 SNES Function norm 4.946821273777e-16
#   0 SNES Function norm 7.799646989076e-10
#   1 SNES Function norm 4.798623582034e-16
#   0 SNES Function norm 7.671381983848e-10
#   1 SNES Function norm 4.761324098949e-16
#   0 SNES Function norm 7.545205037764e-10
#   1 SNES Function norm 4.939340839707e-16
#   0 SNES Function norm 7.421132169229e-10
#   1 SNES Function norm 4.923617824599e-16
#   0 SNES Function norm 7.299066097414e-10
#   1 SNES Function norm 4.947327268425e-16
#   0 SNES Function norm 7.179041607393e-10
#   1 SNES Function norm 4.975198947046e-16
#   0 SNES Function norm 7.060961145984e-10
#   1 SNES Function norm 4.778801457340e-16
#   0 SNES Function norm 6.944846152631e-10
#   1 SNES Function norm 4.938155818806e-16
#   0 SNES Function norm 6.830621349335e-10
#   1 SNES Function norm 5.116695999122e-16
#   0 SNES Function norm 6.718298096378e-10
#   1 SNES Function norm 4.841571839405e-16
#   0 SNES Function norm 6.607786293423e-10
#   1 SNES Function norm 4.845942397285e-16
#   0 SNES Function norm 6.499141239031e-10
#   1 SNES Function norm 4.761412341467e-16
#   0 SNES Function norm 6.392229172253e-10
#   1 SNES Function norm 4.988859422776e-16
#   0 SNES Function norm 6.287128908047e-10
#   1 SNES Function norm 4.746754476152e-16
#   0 SNES Function norm 6.183698847630e-10
#   1 SNES Function norm 4.752276026875e-16
#   0 SNES Function norm 6.082035373640e-10
#   1 SNES Function norm 4.780018783323e-16
#   0 SNES Function norm 5.981976211618e-10
#   1 SNES Function norm 4.846905432070e-16
#   0 SNES Function norm 5.883631083391e-10
#   1 SNES Function norm 4.952478150458e-16
#   0 SNES Function norm 5.786832089427e-10
#   1 SNES Function norm 4.670394992702e-16
#   0 SNES Function norm 5.691697002740e-10
#   1 SNES Function norm 4.867832646667e-16
#   0 SNES Function norm 5.598054446092e-10
#   1 SNES Function norm 4.944239165980e-16
#   0 SNES Function norm 5.506024053256e-10
#   1 SNES Function norm 4.660619535884e-16
#   0 SNES Function norm 5.415436269543e-10
#   1 SNES Function norm 4.833242120139e-16
#   0 SNES Function norm 5.326410228774e-10
#   1 SNES Function norm 4.954395625611e-16
#   0 SNES Function norm 5.238772266115e-10
#   1 SNES Function norm 4.794635633746e-16
#   0 SNES Function norm 5.152654247982e-10
#   1 SNES Function norm 4.772061598431e-16
#   0 SNES Function norm 5.067874454977e-10
#   1 SNES Function norm 4.899459102830e-16
#   0 SNES Function norm 4.984569506844e-10
#   1 SNES Function norm 4.988142553691e-16
#   0 SNES Function norm 4.902548349675e-10
#   1 SNES Function norm 4.992523822772e-16
#   0 SNES Function norm 4.821963182599e-10
#   1 SNES Function norm 4.695474768317e-16
#   0 SNES Function norm 4.742621940543e-10
#   1 SNES Function norm 4.763689200889e-16
#   0 SNES Function norm 4.664659790456e-10
#   1 SNES Function norm 4.794189702669e-16
#   0 SNES Function norm 4.587911187634e-10
#   1 SNES Function norm 4.660633098804e-16
#   0 SNES Function norm 4.512487061201e-10
#   1 SNES Function norm 4.893331855178e-16
#   0 SNES Function norm 4.438248725982e-10
#   1 SNES Function norm 4.894898448802e-16
#   0 SNES Function norm 4.365280508237e-10
#   1 SNES Function norm 4.827386889750e-16
#   0 SNES Function norm 4.293465099929e-10
#   1 SNES Function norm 4.731316944643e-16
#   0 SNES Function norm 4.222876689814e-10
#   1 SNES Function norm 5.096693634640e-16
#   0 SNES Function norm 4.153410920207e-10
#   1 SNES Function norm 4.679511622111e-16
#   0 SNES Function norm 4.085111595851e-10
#   1 SNES Function norm 4.961486897302e-16
#   0 SNES Function norm 4.017922827240e-10
#   1 SNES Function norm 4.699762674799e-16
#   0 SNES Function norm 3.951846212404e-10
#   1 SNES Function norm 4.942109193541e-16
#   0 SNES Function norm 3.886850250743e-10
#   1 SNES Function norm 4.821271875322e-16
#   0 SNES Function norm 3.822935472379e-10
#   1 SNES Function norm 4.984842433534e-16
#   0 SNES Function norm 3.760050995056e-10
#   1 SNES Function norm 4.899865327846e-16
#   0 SNES Function norm 3.698222064017e-10
#   1 SNES Function norm 4.831625993068e-16
#   0 SNES Function norm 3.637396095705e-10
#   1 SNES Function norm 4.821621785606e-16
#   0 SNES Function norm 3.577575421009e-10
#   1 SNES Function norm 4.886242266964e-16
#   0 SNES Function norm 3.518740593216e-10
#   1 SNES Function norm 4.873408590223e-16
#   0 SNES Function norm 3.460870930668e-10
#   1 SNES Function norm 5.112985072175e-16
#   0 SNES Function norm 3.403948917204e-10
#   1 SNES Function norm 4.820187877529e-16
#   0 SNES Function norm 3.347968462365e-10
#   1 SNES Function norm 4.891368398797e-16
#   0 SNES Function norm 3.292911405998e-10
#   1 SNES Function norm 5.068112306862e-16
#   0 SNES Function norm 3.238751480557e-10
#   1 SNES Function norm 4.969883361234e-16
#   0 SNES Function norm 3.185489492031e-10
#   1 SNES Function norm 4.826287847218e-16
#   0 SNES Function norm 3.133096971172e-10
#   1 SNES Function norm 4.929457803390e-16
#   0 SNES Function norm 3.081573832193e-10
#   1 SNES Function norm 4.935077965499e-16
#   0 SNES Function norm 3.030890317362e-10
#   1 SNES Function norm 4.751871263445e-16
#   0 SNES Function norm 2.981047073746e-10
#   1 SNES Function norm 4.930731191598e-16
#   0 SNES Function norm 2.932017932928e-10
#   1 SNES Function norm 4.710818661641e-16
#   0 SNES Function norm 2.883800820352e-10
#   1 SNES Function norm 4.948019351158e-16
#   0 SNES Function norm 2.836368190024e-10
#   1 SNES Function norm 5.096985116926e-16
#   0 SNES Function norm 2.789725413921e-10
#   1 SNES Function norm 4.577398788258e-16
#   0 SNES Function norm 2.743844807912e-10
#   1 SNES Function norm 4.758654391915e-16
#   0 SNES Function norm 2.698715339578e-10
#   1 SNES Function norm 4.814157477978e-16
#   0 SNES Function norm 2.654335123309e-10
#   1 SNES Function norm 4.965310768638e-16
#   0 SNES Function norm 2.610682328232e-10
#   1 SNES Function norm 4.865586377196e-16
#   0 SNES Function norm 2.567744513266e-10
#   1 SNES Function norm 4.936216974962e-16
#   0 SNES Function norm 2.525518068396e-10
#   1 SNES Function norm 4.796039711010e-16
#   0 SNES Function norm 2.483981169440e-10
#   1 SNES Function norm 4.592206147582e-16
#   0 SNES Function norm 2.443126367047e-10
#   1 SNES Function norm 4.765273475999e-16
#   0 SNES Function norm 2.402952733617e-10
#   1 SNES Function norm 4.926535727147e-16
#   0 SNES Function norm 2.363425781350e-10
#   1 SNES Function norm 4.777472148868e-16
# Done?

# %%
fig, axes = plt.subplots()
collection = tripcolor(T_top, axes=axes, cmap='coolwarm')
fig.colorbar(collection);

# %%
fig, axes = plt.subplots()
collection = tripcolor(T_bottom, axes=axes, cmap='coolwarm')
fig.colorbar(collection);

# %%
fig, axes = plt.subplots()
collection = tripcolor(z.sub(0), axes=axes, cmap='coolwarm')
fig.colorbar(collection);

# %%
fig, axes = plt.subplots()
collection = tripcolor(z.sub(1), axes=axes, cmap='coolwarm')
fig.colorbar(collection);

# %%
fig, axes = plt.subplots()
collection = tripcolor(z.sub(2), axes=axes, cmap='coolwarm')
fig.colorbar(collection);

# %%
fig, axes = plt.subplots()
collection = tripcolor(z.sub(3), axes=axes, cmap='coolwarm')
fig.colorbar(collection);

# %%
fig, axes = plt.subplots(nrows=2, sharex=True)

tripcolor(T_top, axes=axes[0],vmin=0,vmax=1, cmap='coolwarm')
axes[0].set_aspect("equal")
axes[0].set_title("Top")
axes[0].set_ylim(0.5,1.0)
axes[0].spines['bottom'].set_visible(False)

tripcolor(T_bottom, axes=axes[1],vmin=0,vmax=1, cmap='coolwarm')
axes[1].set_aspect("equal")
axes[1].set_ylim(0.0,0.5)
axes[1].spines['top'].set_visible(False)

plt.tight_layout(pad=0)
plt.subplots_adjust(hspace=0)

# %%
fig, axes = plt.subplots(nrows=2, sharex=True)


tripcolor(z.sub(0), axes=axes[0],vmin=0,vmax=10, cmap='coolwarm')
axes[0].set_aspect("equal")
axes[0].set_title("Top")
axes[0].set_ylim(0.5,1.0)
axes[0].spines['bottom'].set_visible(False)

tripcolor(z.sub(1), axes=axes[1],vmin=0,vmax=10, cmap='coolwarm')
axes[1].set_aspect("equal")
axes[1].set_ylim(0.0,0.5)
axes[1].spines['top'].set_visible(False)

plt.tight_layout(pad=0)
plt.subplots_adjust(hspace=0)

# %%
axes[0].spines['top']
